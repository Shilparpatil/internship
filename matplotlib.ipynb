# %% [markdown]
# <a href="https://colab.research.google.com/github/Shilparpatil/internship/blob/master/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[1,4,9,16],'g-')
plt.axis([0,6,0,20])
# Out:
# [0, 6, 0, 20]

# %%
import numpy as np
t=np.arange(0.,5.,0.2)
plt.title('graph')
plt.plot(t, t, 'r--', t, t**2, 'b^', t, t**3, 'gs')

# %%
data = {'a': np.arange(10),
        'c': np.random.randint(0, 10, 10),
        'd': np.random.randn(5)}
data['b'] = data['a'] + 10 * np.random.randn(10)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 1000]
plt.figure(figsize=(9, 3))
plt.subplot(131)
plt.title('graph1')
plt.bar(names, values)
plt.subplot(132)
plt.title('graph2')
plt.scatter(names, values)
plt.subplot(133)
plt.title('graph3')
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
# Out:
# Text(0.5, 0.98, 'Categorical Plotting')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
fig=plt.figure()
ax=plt.axes()
x=np.linspace(0,10,1000)
plt.plot(x, np.cos(x-0));
plt.plot(x, np.cos(x-1));
plt.plot(x, np.cos(x-2));
plt.plot(x, np.cos(x-3));
plt.plot(x, np.cos(x-4));
plt.plot(x, np.cos(x-5));

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');

# %%
plt.plot(x, np.sin(x-1));

# %%
plt.plot(x, x + 4, linestyle='-')  
plt.plot(x, x + 5, linestyle='--') 
plt.plot(x, x + 6, linestyle='-.') 
plt.plot(x, x + 7, linestyle=':');

# %%
plt.plot(x, np.sin(x))

plt.xlim(-1, 1)
plt.ylim(-1.5, 1.5);

# %%
plt.plot(x, np.sin(x))

plt.xlim(10, 0)
plt.ylim(1.2, -1.2);

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5]);
plt.axis('equal');

# %%
plt.plot(x, np.sin(x))
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)");

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')

plt.legend();

# %%
ax = plt.axes()
ax.plot(x, np.sin(x))
ax.set(xlim=(0, 10), ylim=(-2, 2),
       xlabel='x', ylabel='sin(x)',
       title='A Simple Plot');
